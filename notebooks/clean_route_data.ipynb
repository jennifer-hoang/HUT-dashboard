# %% [markdown]
# # Data Cleaning for Route Solutions
#
# Date: Jan 24, 2022
#
# This notebook was used for developing the data cleaning script for data exported from Routific.
#
# Routific is an app that is used to optimize delivery routes for the volunteer drivers.
#
# Note: The data shown below is dummy data generated for demonstration purposes only.

# %% [markdown]
# ### Import Packages and Data

# %%
import pandas as pd
import numpy as np
import re

# %%
# Import Data
path = "../data/raw/"
file_name = "Routific Solution Dummy Data - Other 2023-01-17.csv"

raw_data = pd.read_csv(path + file_name)

raw_data
# Out:
#                 Driver Name  Driver Phone  Stop Number Visit Name  \
# 0                  John Doe    1234567890            0        NaN
# 1                  John Doe    1234567890            1   A. Smith
# 2                  John Doe    1234567890            2   B. Smith
# 3                  John Doe    1234567890            3   C. Smith
# 4                  John Doe    1234567890            4   D. Smith
# 5                  John Doe    1234567890            5   E. Smith
# 6                  John Doe    1234567890          999        NaN
# 7                  Mary Doe    1234567890            0        NaN
# 8                  Mary Doe    1234567890            1   A. Smith
# 9                 Mary  Doe    1234567890            2    b smith
# 10       Mary Doe (Route 1)    1234567890            3   C. SMITH
# 11  Mary Doe (Route 2A Sub)    1234567890            4   D. Smith
# 12                 Mary Doe    1234567890            5   E. Smith
# 13                 Mary Doe    1234567890          999        NaN
#
#                 Address  Street  City  State  Zip code  Latitude  ...  \
# 0    1 Main St, M1A 2B3     NaN   NaN    NaN       NaN       NaN  ...
# 1     2 Main St, M1A2B3     NaN   NaN    NaN       NaN       NaN  ...
# 2     2 Main St, m1a2b4     NaN   NaN    NaN       NaN       NaN  ...
# 3    2 Main St, M1A-2B5     NaN   NaN    NaN       NaN       NaN  ...
# 4    2 Main St, M1A 2b6     NaN   NaN    NaN       NaN       NaN  ...
# 5    2 Main St, M1A 2B7     NaN   NaN    NaN       NaN       NaN  ...
# 6    3 Main St, M1A 2B3     NaN   NaN    NaN       NaN       NaN  ...
# 7   1 Maple St, M1A 2B3     NaN   NaN    NaN       NaN       NaN  ...
# 8   1 Maple St, M1A 2B4     NaN   NaN    NaN       NaN       NaN  ...
# 9   1 Maple St, M1A 2B5     NaN   NaN    NaN       NaN       NaN  ...
# 10  1 Maple St, M1A 2B6     NaN   NaN    NaN       NaN       NaN  ...
# 11  1 Maple St, M1A 2B7     NaN   NaN    NaN       NaN       NaN  ...
# 12  1 Maple St, M1A 2B8     NaN   NaN    NaN       NaN       NaN  ...
# 13  1 Maple St, M1A 2B9     NaN   NaN    NaN       NaN       NaN  ...
#
#     Completion/skipped Time  Skipped Reason  Driver Notes FamilyID  \
# 0                       NaN             NaN           NaN      NaN
# 1                     10:20        Not home           NaN      NaN
# 2                     10:30             NaN           NaN      NaN
# 3                     10:40             NaN           NaN      NaN
# 4                     10:50             NaN           NaN      NaN
# 5                     11:00        Not home           NaN      NaN
# 6                       NaN             NaN           NaN      NaN
# 7                       NaN             NaN           NaN      NaN
# 8                       NaN             NaN           NaN      NaN
# 9                       NaN             NaN           NaN      NaN
# 10                      NaN             NaN           NaN      NaN
# 11                      NaN             NaN           NaN      NaN
# 12                      NaN             NaN           NaN      NaN
# 13                      NaN             NaN           NaN      NaN
#
#    Alternate Phone Toy Box Summary  suite  Chicken  Vegetarian  Allergies
# 0              NaN             NaN    NaN      NaN         NaN        NaN
# 1              NaN             NaN    NaN      NaN         NaN        NaN
# 2              NaN             NaN    NaN      NaN         NaN        NaN
# 3              NaN             NaN    NaN      NaN         NaN        NaN
# 4              NaN             NaN    NaN      NaN         NaN        NaN
# 5              NaN             NaN    NaN      NaN         NaN        NaN
# 6              NaN             NaN    NaN      NaN         NaN        NaN
# 7              NaN             NaN    NaN      NaN         NaN        NaN
# 8              NaN             NaN    NaN      NaN         NaN        NaN
# 9              NaN             NaN    NaN      NaN         NaN        NaN
# 10             NaN             NaN    NaN      NaN         NaN        NaN
# 11             NaN             NaN    NaN      NaN         NaN        NaN
# 12             NaN             NaN    NaN      NaN         NaN        NaN
# 13             NaN             NaN    NaN      NaN         NaN        NaN
#
# [14 rows x 37 columns]

# %%
# View raw data columns
raw_data.columns
# Out:
# Index(['Driver Name', 'Driver Phone', 'Stop Number', 'Visit Name', 'Address',
#        'Street', 'City', 'State', 'Zip code', 'Latitude', 'Longitude',
#        'Time window start', 'Time window end', 'Arrive at', 'Start at',
#        'Finish by', 'Duration', 'Idle time', 'Distance(km)', 'Load', 'Phone',
#        'Email', 'Types', 'Notes', 'Notes 2', 'Photo Url', 'Stop Status',
#        'Completion/skipped Time', 'Skipped Reason', 'Driver Notes', 'FamilyID',
#        'Alternate Phone', 'Toy Box Summary', 'suite', 'Chicken', 'Vegetarian',
#        'Allergies'],
#       dtype='object')

# %% [markdown]
# ### Select Columns
#
# Some of the columns are empty or are not relevant for our route analysis, so we'll keep only the columns we need.

# %%
cols = [
    "Driver Name",
    "Stop Number",
    "Visit Name",
    "Address",
    "Start at",
    "Finish by",
    "Distance(km)",
    "Stop Status",
    "Completion/skipped Time",
    "Skipped Reason",
    "Driver Notes",
    "FamilyID",
]

# Clean column names for upload (letters, numbers, underscores only)
col_names = [re.sub("(\s|/|\(|\))", "_", s) for s in cols]

# Select required columns and rename
raw_data = raw_data[cols]
raw_data.columns = col_names


raw_data
# Out:
#                 Driver_Name  Stop_Number Visit_Name              Address  \
# 0                  John Doe            0        NaN   1 Main St, M1A 2B3
# 1                  John Doe            1   A. Smith    2 Main St, M1A2B3
# 2                  John Doe            2   B. Smith    2 Main St, m1a2b4
# 3                  John Doe            3   C. Smith   2 Main St, M1A-2B5
# 4                  John Doe            4   D. Smith   2 Main St, M1A 2b6
# 5                  John Doe            5   E. Smith   2 Main St, M1A 2B7
# 6                  John Doe          999        NaN   3 Main St, M1A 2B3
# 7                  Mary Doe            0        NaN  1 Maple St, M1A 2B3
# 8                  Mary Doe            1   A. Smith  1 Maple St, M1A 2B4
# 9                 Mary  Doe            2    b smith  1 Maple St, M1A 2B5
# 10       Mary Doe (Route 1)            3   C. SMITH  1 Maple St, M1A 2B6
# 11  Mary Doe (Route 2A Sub)            4   D. Smith  1 Maple St, M1A 2B7
# 12                 Mary Doe            5   E. Smith  1 Maple St, M1A 2B8
# 13                 Mary Doe          999        NaN  1 Maple St, M1A 2B9
#
#    Start_at Finish_by  Distance_km_ Stop_Status Completion_skipped_Time  \
# 0     10:00       NaN             0         NaN                     NaN
# 1     10:10     10:20             2     skipped                   10:20
# 2     10:20     10:30             2        done                   10:30
# 3     10:30     10:40             2        done                   10:40
# 4     10:40     10:50             2        done                   10:50
# 5     10:50     11:00             2     skipped                   11:00
# 6     11:30       NaN            10         NaN                     NaN
# 7     10:00       NaN             0         NaN                     NaN
# 8     10:10     10:20             2         NaN                     NaN
# 9     10:20     10:30             2         NaN                     NaN
# 10    10:30     10:40             2         NaN                     NaN
# 11    10:40     10:50             2         NaN                     NaN
# 12    10:50     11:00             2         NaN                     NaN
# 13    30:50       NaN            10         NaN                     NaN
#
#    Skipped_Reason  Driver_Notes  FamilyID
# 0             NaN           NaN       NaN
# 1        Not home           NaN       NaN
# 2             NaN           NaN       NaN
# 3             NaN           NaN       NaN
# 4             NaN           NaN       NaN
# 5        Not home           NaN       NaN
# 6             NaN           NaN       NaN
# 7             NaN           NaN       NaN
# 8             NaN           NaN       NaN
# 9             NaN           NaN       NaN
# 10            NaN           NaN       NaN
# 11            NaN           NaN       NaN
# 12            NaN           NaN       NaN
# 13            NaN           NaN       NaN

# %% [markdown]
# ### Create new features
#
# From `Address`:
# - Postal Code
# - FSA (First 3 Digits of Postal Code)
#
# From `Stop Status`:
# - Stop Completion (binary)
#
# From `File Name`:
# - Dispatch Date
# - Dispatch Type
# - Dispatch Name (Date + Type)

# %%
clean_data = raw_data.copy()

# Create new address variables
clean_data["FSA"] = (clean_data["Address"]
    .str.extract(
        r"([ABCEGHJ-NPRSTVXY]\d[ABCEGHJ-NPRSTV-Z])",
        flags = re.IGNORECASE,
        expand = False
    )
    .str.upper()
)

clean_data["Postal_Code"] = (clean_data["Address"]
    .str.extract(
        r"([ABCEGHJ-NPRSTVXY]\d[ABCEGHJ-NPRSTV-Z][ -]?\d[ABCEGHJ-NPRSTV-Z]\d)",
        flags = re.IGNORECASE,
        expand = False
    )
    .str.upper()
    .str.replace("\W", '', regex = True)
    .str.split(r"([ABCEGHJ-NPRSTVXY]\d[ABCEGHJ-NPRSTV-Z])")
    .str.join(' ')
)

# Create binarized Stop Completion variable
clean_data["Stop_Completion"] = np.where(
    clean_data["Stop_Status"] == "done",
    "1",
    np.where(
        clean_data["Stop_Status"] == "skipped",
        "0",
        np.where(
            (
                clean_data["Stop_Status"].isna()
                & clean_data["Driver_Notes"].isna()
                & clean_data["Distance_km_"].notna()
            ),
            "1",  # If driver forgets to mark status and didn't leave note, assume done
            None,
        ),
    ),
).astype("int")

# Create File Name variable to extract dispatch information
clean_data["File_Name"] = file_name

clean_data["Dispatch_Date"] = clean_data["File_Name"].str.extract(
    r"(\d{4}-\d{2}-\d{2})"
)

clean_data["Dispatch_Type"] = np.where(
    clean_data["File_Name"].str.contains("FSP"),
    "FSP",
    np.where(
        clean_data["File_Name"].str.contains("MOP"),
        "MOP",
        np.where(clean_data["File_Name"].str.contains("Special"), "Special", "Other"),
    ),
)

clean_data["Dispatch_Name"] = clean_data["Dispatch_Date"].str.cat(
    clean_data["Dispatch_Type"], sep=" "
)

# %% [markdown]
# ### Clean Start & Stop Times
#
# Some data points in the `Start_at` and `Finish_by` columns have times that exceed 24 hours. These points are most likely due to the driver forgetting to record the last stop in the app, then closing it within the next few days.
# We'll exclude time points with hours greater than 24 (e.g. "92:10"). Then, we'll convert these times to datetimes in Pandas to calculate the duration.

# %%
# Remove Start/Finish times exceeding 24 hours
clean_data["Start_at"] = np.where(
    clean_data["Start_at"].str.split(':').str.get(0).astype(float) > 23, 
    None, 
    clean_data["Start_at"]
)
clean_data["Finish_by"] = np.where(
    clean_data["Finish_by"].str.split(':').str.get(0).astype(float) > 23, 
    None, 
    clean_data["Finish_by"]
)

# Convert times to Datetime formats and calculate duration between stops in minutes
clean_data["Start_at"] = pd.to_datetime(clean_data["Dispatch_Date"]).dt.tz_localize(
    "US/Eastern"
) + pd.to_timedelta(clean_data["Start_at"] + ":00")
clean_data["Finish_by"] = pd.to_datetime(clean_data["Dispatch_Date"]).dt.tz_localize(
    "US/Eastern"
) + pd.to_timedelta(clean_data["Finish_by"] + ":00")
clean_data["Duration_mins"] = clean_data.groupby("Driver_Name")[
    "Start_at"
].diff() / pd.Timedelta(minutes=1)

# %% [markdown]
# ### Clean Driver and Visit Names
# - Capitalize names using title case, remove added (Route) labels from earlier files, and remove extra spaces

# %%
clean_data['Driver_Name'] = (clean_data['Driver_Name']
    .str.title()
    .str.replace(r'\(Route .+\)', '', regex=True)
    .str.replace(r'\s{2,}', ' ', regex=True)
    .str.strip()
)

clean_data['Visit_Name'] = (clean_data['Visit_Name']
    .str.title()
    .str.replace(r'\s{2,}', ' ', regex=True)
    .str.strip()
)

# %%
clean_data
# Out:
#    Driver_Name  Stop_Number Visit_Name              Address  \
# 0     John Doe            0        NaN   1 Main St, M1A 2B3
# 1     John Doe            1   A. Smith    2 Main St, M1A2B3
# 2     John Doe            2   B. Smith    2 Main St, m1a2b4
# 3     John Doe            3   C. Smith   2 Main St, M1A-2B5
# 4     John Doe            4   D. Smith   2 Main St, M1A 2b6
# 5     John Doe            5   E. Smith   2 Main St, M1A 2B7
# 6     John Doe          999        NaN   3 Main St, M1A 2B3
# 7     Mary Doe            0        NaN  1 Maple St, M1A 2B3
# 8     Mary Doe            1   A. Smith  1 Maple St, M1A 2B4
# 9     Mary Doe            2    B Smith  1 Maple St, M1A 2B5
# 10    Mary Doe            3   C. Smith  1 Maple St, M1A 2B6
# 11    Mary Doe            4   D. Smith  1 Maple St, M1A 2B7
# 12    Mary Doe            5   E. Smith  1 Maple St, M1A 2B8
# 13    Mary Doe          999        NaN  1 Maple St, M1A 2B9
#
#                     Start_at                 Finish_by  Distance_km_  \
# 0  2023-01-17 10:00:00-05:00                       NaT             0
# 1  2023-01-17 10:10:00-05:00 2023-01-17 10:20:00-05:00             2
# 2  2023-01-17 10:20:00-05:00 2023-01-17 10:30:00-05:00             2
# 3  2023-01-17 10:30:00-05:00 2023-01-17 10:40:00-05:00             2
# 4  2023-01-17 10:40:00-05:00 2023-01-17 10:50:00-05:00             2
# 5  2023-01-17 10:50:00-05:00 2023-01-17 11:00:00-05:00             2
# 6  2023-01-17 11:30:00-05:00                       NaT            10
# 7  2023-01-17 10:00:00-05:00                       NaT             0
# 8  2023-01-17 10:10:00-05:00 2023-01-17 10:20:00-05:00             2
# 9  2023-01-17 10:20:00-05:00 2023-01-17 10:30:00-05:00             2
# 10 2023-01-17 10:30:00-05:00 2023-01-17 10:40:00-05:00             2
# 11 2023-01-17 10:40:00-05:00 2023-01-17 10:50:00-05:00             2
# 12 2023-01-17 10:50:00-05:00 2023-01-17 11:00:00-05:00             2
# 13                       NaT                       NaT            10
#
#    Stop_Status Completion_skipped_Time Skipped_Reason  Driver_Notes  FamilyID  \
# 0          NaN                     NaN            NaN           NaN       NaN
# 1      skipped                   10:20       Not home           NaN       NaN
# 2         done                   10:30            NaN           NaN       NaN
# 3         done                   10:40            NaN           NaN       NaN
# 4         done                   10:50            NaN           NaN       NaN
# 5      skipped                   11:00       Not home           NaN       NaN
# 6          NaN                     NaN            NaN           NaN       NaN
# 7          NaN                     NaN            NaN           NaN       NaN
# 8          NaN                     NaN            NaN           NaN       NaN
# 9          NaN                     NaN            NaN           NaN       NaN
# 10         NaN                     NaN            NaN           NaN       NaN
# 11         NaN                     NaN            NaN           NaN       NaN
# 12         NaN                     NaN            NaN           NaN       NaN
# 13         NaN                     NaN            NaN           NaN       NaN
#
#     FSA Postal_Code  Stop_Completion  \
# 0   M1A     M1A 2B3                1
# 1   M1A     M1A 2B3                0
# 2   M1A     M1A 2B4                1
# 3   M1A     M1A 2B5                1
# 4   M1A     M1A 2B6                1
# 5   M1A     M1A 2B7                0
# 6   M1A     M1A 2B3                1
# 7   M1A     M1A 2B3                1
# 8   M1A     M1A 2B4                1
# 9   M1A     M1A 2B5                1
# 10  M1A     M1A 2B6                1
# 11  M1A     M1A 2B7                1
# 12  M1A     M1A 2B8                1
# 13  M1A     M1A 2B9                1
#
#                                             File_Name Dispatch_Date  \
# 0   Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 1   Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 2   Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 3   Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 4   Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 5   Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 6   Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 7   Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 8   Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 9   Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 10  Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 11  Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 12  Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
# 13  Routific Solution Dummy Data - Other 2023-01-1...    2023-01-17
#
#    Dispatch_Type     Dispatch_Name  Duration_mins
# 0          Other  2023-01-17 Other            NaN
# 1          Other  2023-01-17 Other           10.0
# 2          Other  2023-01-17 Other           10.0
# 3          Other  2023-01-17 Other           10.0
# 4          Other  2023-01-17 Other           10.0
# 5          Other  2023-01-17 Other           10.0
# 6          Other  2023-01-17 Other           40.0
# 7          Other  2023-01-17 Other            NaN
# 8          Other  2023-01-17 Other           10.0
# 9          Other  2023-01-17 Other            NaN
# 10         Other  2023-01-17 Other            NaN
# 11         Other  2023-01-17 Other            NaN
# 12         Other  2023-01-17 Other           40.0
# 13         Other  2023-01-17 Other            NaN

# %%
# Write to CSV
clean_path = "../data/clean/"
clean_data.to_csv(clean_path + "Clean_" + file_name, index = False)
